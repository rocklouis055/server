# %%
import pandas as pd
import glob

# %%
print(glob.glob("*"))
# Out:
# ['proj.py', 'tmdb3.csv', 'tmdb2.csv', 'Untitled.ipynb', 'tmdb1.csv']

# %%
d=pd.DataFrame()
for i in glob.glob("*.csv"):
    print(i)
    d=pd.concat([d,pd.read_csv(i,lineterminator='\n',index_col="Unnamed: 0").transpose()])
d
# Out:
# tmdb3.csv
# tmdb2.csv
# tmdb1.csv
#        adult                     backdrop_path  \
# 70000  False  /f75sd2ULYN0aWCnUhO0fm4aV1ch.jpg
# 70001  False  /Am8SJWHvnMRGHA1z54vg3e2lIxV.jpg
# 70002  False  /phwUPMMSrj8Cil5OAvEiasCFmWz.jpg
# 70003  False  /bRImkjAgV1MrGuWlL3XTujkfVsd.jpg
# 70004  False                               NaN
# ...      ...                               ...
# 39995  False  /5IsTrvzM3dEB5w4Yj5FNX3j0FIK.jpg
# 39996  False                               NaN
# 39997  False  /m9GuOIqGJyjxLI7TtqzhAzMBjwv.jpg
# 39998  False  /8k5OEMrBuiN51yVnAYZPAnwPtvW.jpg
# 39999  False  /vnXwqJ7TQtJJaPsufVeg0kF1dlr.jpg
#
#                                    belongs_to_collection budget  \
# 70000                                                NaN      0
# 70001                                                NaN      0
# 70002                                                NaN      0
# 70003                                                NaN      0
# ...

# %%
# a=pd.read_csv("tmdb3.csv",lineterminator='\n',index_col=).transpose()
a=pd.read_csv(i,lineterminator='\n',index_col="Unnamed: 0").transpose()
a
# Out:
#        adult                     backdrop_path belongs_to_collection budget  \
# 70000  False  /f75sd2ULYN0aWCnUhO0fm4aV1ch.jpg                   NaN      0
# 70001  False  /Am8SJWHvnMRGHA1z54vg3e2lIxV.jpg                   NaN      0
# 70002  False  /phwUPMMSrj8Cil5OAvEiasCFmWz.jpg                   NaN      0
# 70003  False  /bRImkjAgV1MrGuWlL3XTujkfVsd.jpg                   NaN      0
# 70004  False                               NaN                   NaN      0
# ...      ...                               ...                   ...    ...
# 99994  False  /hLZkOUrh4m7DfYbzv3jDmzmag43.jpg                   NaN      0
# 99995  False  /jQvfxZDmxbKujIPjaJrYxKyunmE.jpg                   NaN      0
# 99997  False  /uAG9D0mTEHhYsJ20W8Pk8i3SDn8.jpg                   NaN      0
# 99998  False  /wS0lvCKBe2FdCHhXQgSPU8lozbG.jpg                   NaN      0
# 99999  False  /xKR8HyxCi3E4R7IwR8deiG59V9f.jpg                   NaN      0
#
# ...

# %%
d.columns
# Out:
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
'2' in d.index
# Out:
# True

# %%
"https://image.tmdb.org/t/p/original"+d.loc['2']['poster_path']
# Out:
# 'https://image.tmdb.org/t/p/original/ojDg0PGvs6R9xYFodRct2kdI6wC.jpg'
